# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY')

# Langsmith Tracking
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2']="true"
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x0000022F5E554820> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000022F3CEA7E80> root_client=<openai.OpenAI object at 0x0000022F5E554DC0> root_async_client=<openai.AsyncOpenAI object at 0x0000022F5E555690> model_name='gpt-4o' openai_api_key=SecretStr('**********') openai_proxy=''

# %%
# Input and get response from llm

result = llm.invoke("What is generative AI")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence systems designed to generate new content, such as text, images, audio, or other media, that is similar to human-created content. These systems use machine learning models, particularly deep learning models, to identify patterns and structures within existing data and then produce novel outputs that mimic these patterns.\n\nKey technologies and approaches in generative AI include:\n\n1. **Generative Adversarial Networks (GANs)**: These consist of two neural networks, a generator and a discriminator, that work against each other. The generator creates new data instances, while the discriminator evaluates them. This adversarial process continues until the generator produces outputs indistinguishable from real data.\n\n2. **Variational Autoencoders (VAEs)**: These are models that learn to encode input data into a compressed latent space and then decode it back to generate new data. VAEs are particularly useful for generating variations of data.\n\n3. **Transformer Models**: These are particularly prominent in natural language processing (NLP) tasks. Models like GPT (Generative Pre-trained Transformer) can generate coherent and contextually relevant text based on a given prompt.\n\n4. **Diffusion Models**: A newer approach that involves gradually adding noise to data and then learning to reverse this process to generate new data samples. These models have been effective in generating high-quality images.\n\nGenerative AI has numerous applications, including:\n\n- **Content Creation**: Generating articles, stories, poetry, and other forms of written content.\n- **Art and Design**: Creating artwork, designs, and even music.\n- **Data Augmentation**: Generating additional training data for machine learning models.\n- **Simulation and Modeling**: Creating realistic simulations for various industries, such as automotive, healthcare, and entertainment.\n- **Personalization**: Developing personalized recommendations and experiences in e-commerce, media, and other fields.\n\nWhile generative AI presents exciting possibilities, it also raises ethical and practical concerns, such as the potential for creating misleading or harmful content, intellectual property issues, and the need for substantial computational resources.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 421, 'prompt_tokens': 12, 'total_tokens': 433, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_83554c687e', 'finish_reason': 'stop', 'logprobs': None} id='run-1b75a039-f064-470e-b51e-e4f88eda17f6-0' usage_metadata={'input_tokens': 12, 'output_tokens': 421, 'total_tokens': 433}

# %%
# Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are an expert AI Engineer. Provide me answers based on the question')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}'))])

# %%
# Chain
chain=prompt|llm
response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a tool designed for developers who are working with language models, particularly those using LangChain. It provides a suite of features aimed at improving the development, testing, and deployment of applications that leverage language models. Key functionalities of Langsmith include:\n\n1. **Debugging and Testing**: Langsmith offers tools to help developers identify and fix issues in their language model applications. This includes the ability to test different prompt configurations and manage various versions of language models efficiently.\n\n2. **Monitoring and Evaluation**: Developers can use Langsmith to monitor the performance of their models in real-time. It provides insights into how models are responding to inputs, allowing for better evaluation of their effectiveness and accuracy.\n\n3. **Experimentation**: Langsmith supports running experiments with different model setups or configurations. This feature helps in fine-tuning models by comparing the results of various approaches, leading to more informed decisions about model improvements.\n\n4. **Integration with LangChain**: As a tool developed with LangChain in mind, Langsmith integrates seamlessly with this ecosystem. This makes it easier for developers already using LangChain to adopt Langsmith in their workflows.\n\nOverall, Langsmith is designed to streamline the process of developing and maintaining applications that rely on language models, promoting efficiency and accuracy in their deployment.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 258, 'prompt_tokens': 33, 'total_tokens': 291, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_83554c687e', 'finish_reason': 'stop', 'logprobs': None} id='run-3fdc5c4b-31fd-46b5-b749-a6e563c77744-0' usage_metadata={'input_tokens': 33, 'output_tokens': 258, 'total_tokens': 291}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
# stroutput Parser

from langchain_core.output_parsers import StrOutputParser

output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a platform designed to enhance the development experience for applications that utilize large language models (LLMs). It provides tools for testing, evaluating, and monitoring LLM-driven applications, helping developers to refine their models over time. Langsmith offers features to track performance, assess the effectiveness of prompts, and visualize how changes in code affect outputs. This enables developers to systematically improve their applications by understanding and addressing issues in the behavior of LLMs. The platform is particularly useful for those looking to build robust and reliable applications that leverage the capabilities of LLMs.

# %% [markdown]
# Affiche le contenu de "content" (que la réponse à la question)
